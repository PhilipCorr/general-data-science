# %%
import pandas as pd

# %%
sub = pd.read_csv("en_sample_submission.csv")
test = pd.read_csv("en_test.csv")
train = pd.read_csv("en_train.csv")

# %%
sub.head()
# Out:
#     id      after
# 0  0_0    Another
# 1  0_1  religious
# 2  0_2     family
# 3  0_3         is
# 4  0_4         of

# %%
train.head()
# Out:
#    sentence_id  token_id  class         before          after
# 0            0         0  PLAIN  Brillantaisia  Brillantaisia
# 1            0         1  PLAIN             is             is
# 2            0         2  PLAIN              a              a
# 3            0         3  PLAIN          genus          genus
# 4            0         4  PLAIN             of             of

# %%
test.head(50)
# Out:
#     sentence_id  token_id          before
# 0             0         0         Another
# 1             0         1       religious
# 2             0         2          family
# 3             0         3              is
# 4             0         4              of
# 5             0         5          Hazrat
# 6             0         6          Sayyed
# 7             0         7           Ahmad
# 8             0         8             and
# 9             0         9             his
# 10            0        10          nephew
# 11            0        11          Hazrat
# 12            0        12           Abdul
# 13            0        13             Haq
# 14            0        14               .
# 15            1         0             The
# 16            1         1            free
# 17            1         2          webapp
# 18            1         3   functionality
# 19            1         4        contains
# 20            1         5  advertisements
# ...
