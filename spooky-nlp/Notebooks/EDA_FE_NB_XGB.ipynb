# %% [markdown]
# # EDA

# %%
import pandas as pd
import numpy as np
import seaborn as sns
from matplotlib import pyplot as plt
# %config InlineBackend.figure_format = 'svg' # plots look nicer in svg
# %matplotlib inline
sns.set()
pd.options.display.max_colwidth = 160

# %% [markdown]
# ## Load data

# %%
train = pd.read_csv('../Data/train.csv')
test  = pd.read_csv('../Data/test.csv')

# %%
train.shape, test.shape
# Out:
# ((19579, 3), (8392, 2))

# %%
train.head(2)
# Out:
#         id  \
# 0  id26305
# 1  id17569
#
#                                                                                                                                                               text  \
# 0  This process, however, afforded me no means of ascertaining the dimensions of my dungeon; as I might make its circuit, and return to the point whence I set ...
# 1                                                                                          It never once occurred to me that the fumbling might be a mere mistake.
#
#   author
# 0    EAP
# 1    HPL

# %%
sns.countplot(x=train.author);

# %% [markdown]
# We see that classes are balanced

# %% [markdown]
# # Preprocessing

# %%
import spacy
import nltk

# %%
nlp = spacy.load('en')

# %%
# add custom stop words
nlp.vocab["'s"].is_stop = True
for word in spacy.lang.en.STOP_WORDS:
    lexeme = nlp.vocab[word]
    lexeme.is_stop = True

# %% [markdown]
# Define function to replace named entities in text

# %%
def replace_ents(doc):
    prefix = 'ent__'
    text = str(doc.doc)
    for ent in doc.ents:
        text = text.replace(ent.orth_, prefix + ent.label_)
    return text

# %% [markdown]
# Define func to preprocess text data. Here I am doing the following:
# - Parsing text with spaCy
# - Handcrafting new features identifying number of:
#     - characters
#     - words
#     - punctuation characters
#     - named entities
#     - noun chunks
#     - unique words
#     - stop words
#     - characters by word
# - Replace named entities with tags like 'ent_ORG'
# - Lemmatize
# - Delete stopwords
#
# I leave 3 different versions of text in order to try which fits best with CV.

# %%
def preprocess(df):
    print('Started parsing...')
    doc = df.text.apply(nlp)
    print('Text parsed')
    
    df['n_char']   = df.text.apply(len)
    df['n_words']  = doc.apply(lambda x: len([t for t in x if not t.is_punct]))
    df['n_punct']  = doc.apply(lambda x: len([t for t in x if t.is_punct]))
    df['n_ents']   = doc.apply(lambda x: len(x.ents))
    df['n_chunks'] = doc.apply(lambda x: len(list(x.noun_chunks)))
    df['n_unique_words'] = doc.apply(lambda x: len(set([t.lower_ for t in x if not t.is_punct])))
    df['n_stop_words']   = doc.apply(lambda x: len([t for t in x if t.is_stop]))
    df['char_by_word']   = doc.apply(lambda x: np.mean([len(t.orth_) for t in x if not t.is_punct]))
    print('Features created')
    
    df['text_ent_repl'] = doc.apply(replace_ents)
    print('Entities replaced')
    
    clean_and_lemmatize = lambda x: ' '.join([t.lemma_ for t in x if not t.is_punct and not t.is_stop])
    df['text_cleaned'] = doc.apply(clean_and_lemmatize)
    print('Text cleaned')

# %%
# %%time
preprocess(train)
# Out:
# Started parsing...
# Text parsed
# Features created
# Entities replaced
# Text cleaned
# CPU times: user 4min 12s, sys: 10.5 s, total: 4min 22s
# Wall time: 3min 11s

# %%
# %%time
preprocess(test)
# Out:
# Started parsing...
# Text parsed
# Features created
# Entities replaced
# Text cleaned
# CPU times: user 1min 45s, sys: 4.06 s, total: 1min 49s
# Wall time: 1min 18s

# %% [markdown]
# ## Visulizations

# %% [markdown]
# Split train by authors to make distinct visualizations

# %%
eap = train.loc[train.author == 'EAP']
hpl = train.loc[train.author == 'HPL']
mws = train.loc[train.author == 'MWS']

eap_t = eap.text_cleaned
hpl_t = hpl.text_cleaned
mws_t = mws.text_cleaned

# %% [markdown]
# ### Plot frequncies

# %%
fd = nltk.FreqDist([y for x in train.text_cleaned.str.split() for y in x])

fd_eap = nltk.FreqDist([y for x in eap_t.str.split() for y in x])
fd_hpl = nltk.FreqDist([y for x in hpl_t.str.split() for y in x])
fd_mws = nltk.FreqDist([y for x in mws_t.str.split() for y in x])

# %%
fd.plot(30, title='Overall')
fd_eap.plot(30, title='EAP')
fd_hpl.plot(30, title='HPL')
fd_mws.plot(30, title='MWS')

# %% [markdown]
# We see that top frequent words differ for the most part depending on the author, though they have some common words like 'man', 'see'.

# %% [markdown]
# ### Word Clouds

# %%
from wordcloud import WordCloud
sns.set_style({'axes.grid' : False})

# %%
WordCloud(min_font_size=8, width=1000, height=400).generate(' '.join(eap_t)).to_image()
# Out:
# <PIL.Image.Image image mode=RGB size=1000x400 at 0x114C26F60>

# %%
WordCloud(min_font_size=8, width=1000, height=400, colormap='cubehelix_r').generate(' '.join(hpl_t)).to_image()
# Out:
# <PIL.Image.Image image mode=RGB size=1000x400 at 0x1135A5160>

# %%
WordCloud(min_font_size=8, width=1000, height=400, colormap='hot').generate(' '.join(mws_t)).to_image()
# Out:
# <PIL.Image.Image image mode=RGB size=1000x400 at 0x1135AF400>

# %% [markdown]
# ### Meta-features distributions

# %%
sns.set()

# %%
def drop_outliers(s):
    med = s.mean()
    std = s.std()
    return s[(med - 3*std <= s) & (s <= med + 3*std)]

# %%
f, ax = plt.subplots(figsize=(7,4))
sns.kdeplot(drop_outliers(eap.n_char), shade=True, color="r");
sns.kdeplot(drop_outliers(hpl.n_char), shade=True, color="g");
sns.kdeplot(drop_outliers(mws.n_char), shade=True, color="b");
ax.legend(labels=['EAP', 'HPL', 'MWS']);

# %% [markdown]
# We see that EAP's texts are a little bit shorter on average while HPL's are longer

# %%
f, ax = plt.subplots(figsize=(7,4))
sns.kdeplot(drop_outliers(eap.n_punct), shade=True, color="r");
sns.kdeplot(drop_outliers(hpl.n_punct), shade=True, color="g");
sns.kdeplot(drop_outliers(mws.n_punct), shade=True, color="b");
ax.legend(labels=['EAP', 'HPL', 'MWS']);

# %% [markdown]
# Here we see some difference in distribution between HPL and others

# %% [markdown]
# # Models

# %%
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from sklearn.model_selection import cross_val_score, train_test_split
from sklearn.preprocessing import LabelEncoder

from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import MultinomialNB

from sklearn.pipeline import Pipeline

# %%
y = train.author

# %% [markdown]
# ## Only text

# %% [markdown]
# ### CountVect + untouched text

# %%
vectorizer = CountVectorizer(
    token_pattern=r'\w{1,}',
    ngram_range=(1, 2), stop_words='english'
)
X = vectorizer.fit_transform(train.text)

# %%
# %%time
scores = cross_val_score(LogisticRegression(), X, y, cv=10, n_jobs=-1, scoring='neg_log_loss')
print('LogLoss: %.3f +- %.3f' % (-np.mean(scores), 2*np.std(scores)))
# Out:
# LogLoss: 0.502 +- 0.024
# CPU times: user 234 ms, sys: 46.1 ms, total: 280 ms
# Wall time: 16min 58s

# %%
# %%time
scores = cross_val_score(MultinomialNB(), X, y, cv=10, n_jobs=-1, scoring='neg_log_loss')
print('LogLoss: %.3f +- %.3f' % (-np.mean(scores), 2*np.std(scores)))
# Out:
# LogLoss: 0.443 +- 0.034
# CPU times: user 252 ms, sys: 50.6 ms, total: 302 ms
# Wall time: 1.26 s

# %% [markdown]
# 0.443 - Nice performance with just NB!

# %% [markdown]
# ### CountVect + cleaned text

# %%
vectorizer = CountVectorizer(ngram_range=(1,2))
X = vectorizer.fit_transform(train.text_cleaned)

# %%
# %%time
scores = cross_val_score(LogisticRegression(), X, y, cv=10, n_jobs=-1, scoring='neg_log_loss')
print('LogLoss: %.3f +- %.3f' % (-np.mean(scores), 2*np.std(scores)))
# Out:
# LogLoss: 0.496 +- 0.029
# CPU times: user 247 ms, sys: 49.6 ms, total: 297 ms
# Wall time: 11.5 s

# %%
# %%time
scores = cross_val_score(MultinomialNB(), X, y, cv=10, n_jobs=-1, scoring='neg_log_loss')
print('LogLoss: %.3f +- %.3f' % (-np.mean(scores), 2*np.std(scores)))
# Out:
# LogLoss: 0.483 +- 0.047
# CPU times: user 223 ms, sys: 46.2 ms, total: 269 ms
# Wall time: 630 ms

# %% [markdown]
# ### CountVect + replaced entities text

# %%
vectorizer = CountVectorizer(token_pattern=r'\w{1,}', stop_words='english', ngram_range=(1,2))
X = vectorizer.fit_transform(train.text_ent_repl)

# %%
# %%time
scores = cross_val_score(LogisticRegression(), X, y, cv=10, n_jobs=-1, scoring='neg_log_loss')
print('LogLoss: %.3f +- %.3f' % (-np.mean(scores), 2*np.std(scores)))
# Out:
# LogLoss: 0.553 +- 0.022
# CPU times: user 239 ms, sys: 52.5 ms, total: 291 ms
# Wall time: 11.8 s

# %%
# %%time
scores = cross_val_score(MultinomialNB(), X, y, cv=10, n_jobs=-1, scoring='neg_log_loss')
print('LogLoss: %.3f +- %.3f' % (-np.mean(scores), 2*np.std(scores)))
# Out:
# LogLoss: 0.518 +- 0.034
# CPU times: user 214 ms, sys: 43.9 ms, total: 258 ms
# Wall time: 632 ms

# %% [markdown]
# Seems like replacing named entities doesn't help

# %% [markdown]
# ### TF-IDF + cleaned text

# %%
vectorizer = TfidfVectorizer(
    token_pattern=r'\w{1,}', ngram_range=(1, 1), 
    use_idf=True, smooth_idf=True, sublinear_tf=True,
)
X = vectorizer.fit_transform(train.text_cleaned)

# %%
# %%time
scores = cross_val_score(LogisticRegression(), X, y, cv=10, n_jobs=-1, scoring='neg_log_loss')
print('LogLoss: %.3f +- %.3f' % (-np.mean(scores), 2*np.std(scores)))
# Out:
# LogLoss: 0.603 +- 0.015
# CPU times: user 187 ms, sys: 48.7 ms, total: 236 ms
# Wall time: 1.54 s

# %%
# %%time
scores = cross_val_score(MultinomialNB(), X, y, cv=10, n_jobs=-1, scoring='neg_log_loss')
print('LogLoss: %.3f +- %.3f' % (-np.mean(scores), 2*np.std(scores)))
# Out:
# LogLoss: 0.584 +- 0.014
# CPU times: user 177 ms, sys: 47.9 ms, total: 225 ms
# Wall time: 517 ms

# %% [markdown]
# tfidf performs worse than simple count vect

# %% [markdown]
# ## Only meta-features

# %%
import xgboost as xgb
import lightgbm as lgb

# %%
drop = ['id', 'text', 'text_cleaned', 'text_ent_repl']

# %%
X_meta = train.drop(drop + ['author'], axis=1)

# %%
# %%time
lgbc = lgb.LGBMClassifier(objective='multiclass', n_estimators=100)
scores = cross_val_score(lgbc, X_meta, y, cv=4, n_jobs=1, scoring='neg_log_loss')
print('LogLoss: %.3f +- %.3f' % (-np.mean(scores), 2*np.std(scores)))
# Out:
# /Users/pcorr/anaconda3/envs/py36/lib/python3.6/site-packages/lightgbm/basic.py:642: UserWarning: max_bin keyword has been found in `params` and will be ignored. Please use max_bin argument of the Dataset constructor to pass this parameter.
#   'Please use {0} argument of the Dataset constructor to pass this parameter.'.format(key))
# /Users/pcorr/anaconda3/envs/py36/lib/python3.6/site-packages/lightgbm/basic.py:648: LGBMDeprecationWarning: The `max_bin` parameter is deprecated and will be removed in 2.0.12 version. Please use `params` to pass this parameter.
#   'Please use `params` to pass this parameter.', LGBMDeprecationWarning)
# /Users/pcorr/anaconda3/envs/py36/lib/python3.6/site-packages/lightgbm/basic.py:642: UserWarning: max_bin keyword has been found in `params` and will be ignored. Please use max_bin argument of the Dataset constructor to pass this parameter.
#   'Please use {0} argument of the Dataset constructor to pass this parameter.'.format(key))
# /Users/pcorr/anaconda3/envs/py36/lib/python3.6/site-packages/lightgbm/basic.py:648: LGBMDeprecationWarning: The `max_bin` parameter is deprecated and will be removed in 2.0.12 version. Please use `params` to pass this parameter.
#   'Please use `params` to pass this parameter.', LGBMDeprecationWarning)
# /Users/pcorr/anaconda3/envs/py36/lib/python3.6/site-packages/lightgbm/basic.py:642: UserWarning: max_bin keyword has been found in `params` and will be ignored. Please use max_bin argument of the Dataset constructor to pass this parameter.
#   'Please use {0} argument of the Dataset constructor to pass this parameter.'.format(key))
# /Users/pcorr/anaconda3/envs/py36/lib/python3.6/site-packages/lightgbm/basic.py:648: LGBMDeprecationWarning: The `max_bin` parameter is deprecated and will be removed in 2.0.12 version. Please use `params` to pass this parameter.
#   'Please use `params` to pass this parameter.', LGBMDeprecationWarning)
# /Users/pcorr/anaconda3/envs/py36/lib/python3.6/site-packages/lightgbm/basic.py:642: UserWarning: max_bin keyword has been found in `params` and will be ignored. Please use max_bin argument of the Dataset constructor to pass this parameter.
#   'Please use {0} argument of the Dataset constructor to pass this parameter.'.format(key))
# /Users/pcorr/anaconda3/envs/py36/lib/python3.6/site-packages/lightgbm/basic.py:648: LGBMDeprecationWarning: The `max_bin` parameter is deprecated and will be removed in 2.0.12 version. Please use `params` to pass this parameter.
#   'Please use `params` to pass this parameter.', LGBMDeprecationWarning)
# LogLoss: 0.961 +- 0.005
# CPU times: user 4.2 s, sys: 4.51 s, total: 8.7 s
# Wall time: 5.53 s

# %%
# %%time
xgbc = xgb.XGBClassifier(objective='multi:softprob', n_estimators=200)
scores = cross_val_score(xgbc, X_meta, y, cv=4, n_jobs=4, scoring='neg_log_loss')
print('LogLoss: %.3f +- %.3f' % (-np.mean(scores), 2*np.std(scores)))
# Out:
# LogLoss: 0.959 +- 0.005
# CPU times: user 122 ms, sys: 37 ms, total: 159 ms
# Wall time: 3.52 s

# %%
xgbc.fit(X_meta, y);
xgb.plot_importance(xgbc);

# %% [markdown]
# ## Stack 'em

# %%
from sklearn.model_selection import StratifiedKFold
from sklearn import metrics

# %%
def add_prob_features(vectorizer, col, model, prefix, cv=5):
    vectorizer.fit(train[col].append(test[col]))
    X = vectorizer.transform(train[col])
    X_test = vectorizer.transform(test[col])
    
    cv_scores = []
    pred_test = 0
    pred_train = np.zeros([train.shape[0], 3])
    kf = StratifiedKFold(n_splits=cv, shuffle=True, random_state=123)
    
    print('CV started')
    for train_index, dev_index in kf.split(X, y):
        X_train, X_dev = X[train_index], X[dev_index]
        y_train, y_dev = y[train_index], y[dev_index]
        
        model.fit(X_train, y_train)
        pred_dev   = model.predict_proba(X_dev)
        pred_test += model.predict_proba(X_test)
    
        pred_train[dev_index, :] = pred_dev
        cv_scores.append(metrics.log_loss(y_dev, pred_dev))
        print('.', end='')
        
    print('')
    print("Mean CV LogLoss: %.3f" % (np.mean(cv_scores)))
    pred_test /= cv

    train[prefix+'eap'] = pred_train[:, 0]
    train[prefix+'hpl'] = pred_train[:, 1]
    train[prefix+'mws'] = pred_train[:, 2]
    
    test[prefix+'eap'] = pred_test[:, 0]
    test[prefix+'hpl'] = pred_test[:, 1]
    test[prefix+'mws'] = pred_test[:, 2]

# %%
vectorizer = CountVectorizer(
    token_pattern=r'\w{1,}',
    ngram_range=(1, 2), stop_words='english'
)
add_prob_features(vectorizer, 'text', MultinomialNB(), 'nb_ctv_', cv=40)
# Out:
# CV started
# ........................................
# Mean CV LogLoss: 0.433

# %%
vectorizer = TfidfVectorizer(
    token_pattern=r'\w{1,}', ngram_range=(1, 1), 
    use_idf=True, smooth_idf=True, sublinear_tf=True,
)
add_prob_features(vectorizer, 'text_cleaned', MultinomialNB(), 'nb_tfv_', cv=40)
# Out:
# CV started
# ........................................
# Mean CV LogLoss: 0.576

# %%
vectorizer = TfidfVectorizer(
    ngram_range=(1, 5), analyzer='char'
)
add_prob_features(vectorizer, 'text', MultinomialNB(), 'nb_char_', cv=40)
# Out:
# CV started
# ........................................
# Mean CV LogLoss: 0.732

# %%
vectorizer = CountVectorizer(
    token_pattern=r'\w{1,}',
    ngram_range=(1, 2), stop_words='english'
)
add_prob_features(vectorizer, 'text_ent_repl', MultinomialNB(), 'nb_ent_', cv=40)
# Out:
# CV started
# ........................................
# Mean CV LogLoss: 0.510

# %%
X = train.drop(drop + ['author'], axis=1)

# %%
# %%time
lgbc = lgb.LGBMClassifier(objective='multiclass', n_estimators=150, num_leaves=10)
scores = cross_val_score(lgbc, X, y, cv=4, n_jobs=1, scoring='neg_log_loss')
print('LogLoss: %.3f +- %.3f' % (-np.mean(scores), 2*np.std(scores)))
# Out:
# /Users/pcorr/anaconda3/envs/py36/lib/python3.6/site-packages/lightgbm/basic.py:642: UserWarning: max_bin keyword has been found in `params` and will be ignored. Please use max_bin argument of the Dataset constructor to pass this parameter.
#   'Please use {0} argument of the Dataset constructor to pass this parameter.'.format(key))
# /Users/pcorr/anaconda3/envs/py36/lib/python3.6/site-packages/lightgbm/basic.py:648: LGBMDeprecationWarning: The `max_bin` parameter is deprecated and will be removed in 2.0.12 version. Please use `params` to pass this parameter.
#   'Please use `params` to pass this parameter.', LGBMDeprecationWarning)
# /Users/pcorr/anaconda3/envs/py36/lib/python3.6/site-packages/lightgbm/basic.py:642: UserWarning: max_bin keyword has been found in `params` and will be ignored. Please use max_bin argument of the Dataset constructor to pass this parameter.
#   'Please use {0} argument of the Dataset constructor to pass this parameter.'.format(key))
# /Users/pcorr/anaconda3/envs/py36/lib/python3.6/site-packages/lightgbm/basic.py:648: LGBMDeprecationWarning: The `max_bin` parameter is deprecated and will be removed in 2.0.12 version. Please use `params` to pass this parameter.
#   'Please use `params` to pass this parameter.', LGBMDeprecationWarning)
# /Users/pcorr/anaconda3/envs/py36/lib/python3.6/site-packages/lightgbm/basic.py:642: UserWarning: max_bin keyword has been found in `params` and will be ignored. Please use max_bin argument of the Dataset constructor to pass this parameter.
#   'Please use {0} argument of the Dataset constructor to pass this parameter.'.format(key))
# /Users/pcorr/anaconda3/envs/py36/lib/python3.6/site-packages/lightgbm/basic.py:648: LGBMDeprecationWarning: The `max_bin` parameter is deprecated and will be removed in 2.0.12 version. Please use `params` to pass this parameter.
#   'Please use `params` to pass this parameter.', LGBMDeprecationWarning)
# /Users/pcorr/anaconda3/envs/py36/lib/python3.6/site-packages/lightgbm/basic.py:642: UserWarning: max_bin keyword has been found in `params` and will be ignored. Please use max_bin argument of the Dataset constructor to pass this parameter.
#   'Please use {0} argument of the Dataset constructor to pass this parameter.'.format(key))
# /Users/pcorr/anaconda3/envs/py36/lib/python3.6/site-packages/lightgbm/basic.py:648: LGBMDeprecationWarning: The `max_bin` parameter is deprecated and will be removed in 2.0.12 version. Please use `params` to pass this parameter.
#   'Please use `params` to pass this parameter.', LGBMDeprecationWarning)
# LogLoss: 0.345 +- 0.015
# CPU times: user 5.32 s, sys: 2.12 s, total: 7.44 s
# Wall time: 3.83 s

# %%
# %%time
xgbc = xgb.XGBClassifier(objective='multi:softprob', n_estimators=150)
scores = cross_val_score(xgbc, X, y, cv=4, n_jobs=1, scoring='neg_log_loss')
print('LogLoss: %.3f +- %.3f' % (-np.mean(scores), 2*np.std(scores)))
# Out:
# LogLoss: 0.344 +- 0.014
# CPU times: user 23.1 s, sys: 1.19 s, total: 24.3 s
# Wall time: 8.76 s

# %%
# %%time
xgbc.fit(X, y);
# Out:
# CPU times: user 7.24 s, sys: 302 ms, total: 7.55 s
# Wall time: 2.84 s
# XGBClassifier(base_score=0.5, colsample_bylevel=1, colsample_bytree=1,
#        gamma=0, learning_rate=0.1, max_delta_step=0, max_depth=3,
#        min_child_weight=1, missing=None, n_estimators=150, nthread=-1,
#        objective='multi:softprob', reg_alpha=0, reg_lambda=1,
#        scale_pos_weight=1, seed=0, silent=True, subsample=1)

# %%
xgb.plot_importance(xgbc);

# %%
def sub(est, name='sub.csv'):
    sub = pd.DataFrame(est.predict_proba(test.drop(drop, axis=1)), columns=['EAP', 'HPL', 'MWS'])
    sub.insert(0, 'id', test.id)
    sub.to_csv(name, index=False)

# %%
from sklearn import model_selection

# %%
clf = xgb.XGBClassifier(objective = 'multi:softprob', nthread=1)

parameters = {
    'n_estimators': [150],
    'max_depth': [3],
    'subsample': [0.65],
    'colsample_bytree': [0.95],
    'min_child_weight': [1],
}

clf = model_selection.GridSearchCV(clf, parameters, n_jobs=4, verbose=1, scoring='neg_log_loss', refit=True)

# %%
clf.fit(X, y);
# Out:
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [Parallel(n_jobs=4)]: Done   3 out of   3 | elapsed:    5.6s finished

# %%
-clf.best_score_
# Out:
# 0.34300154006076788

# %%
sub(clf.best_estimator_)

# %%
train.columns
# Out:
# Index(['id', 'text', 'author', 'n_char', 'n_words', 'n_punct', 'n_ents',
#        'n_chunks', 'n_unique_words', 'n_stop_words', 'char_by_word',
#        'text_ent_repl', 'text_cleaned', 'nb_ctv_eap', 'nb_ctv_hpl',
#        'nb_ctv_mws', 'nb_tfv_eap', 'nb_tfv_hpl', 'nb_tfv_mws', 'nb_char_eap',
#        'nb_char_hpl', 'nb_char_mws', 'nb_ent_eap', 'nb_ent_hpl', 'nb_ent_mws'],
#       dtype='object')

# %%
drop
# Out:
# ['id', 'text', 'text_cleaned', 'text_ent_repl']

# %%
train.drop(drop + ['author'], axis=1).columns
# Out:
# Index(['n_char', 'n_words', 'n_punct', 'n_ents', 'n_chunks', 'n_unique_words',
#        'n_stop_words', 'char_by_word', 'nb_ctv_eap', 'nb_ctv_hpl',
#        'nb_ctv_mws', 'nb_tfv_eap', 'nb_tfv_hpl', 'nb_tfv_mws', 'nb_char_eap',
#        'nb_char_hpl', 'nb_char_mws', 'nb_ent_eap', 'nb_ent_hpl', 'nb_ent_mws'],
#       dtype='object')

# %%
test.columns
# Out:
# Index(['id', 'text', 'n_char', 'n_words', 'n_punct', 'n_ents', 'n_chunks',
#        'n_unique_words', 'n_stop_words', 'char_by_word', 'text_ent_repl',
#        'text_cleaned', 'nb_ctv_eap', 'nb_ctv_hpl', 'nb_ctv_mws', 'nb_tfv_eap',
#        'nb_tfv_hpl', 'nb_tfv_mws', 'nb_char_eap', 'nb_char_hpl', 'nb_char_mws',
#        'nb_ent_eap', 'nb_ent_hpl', 'nb_ent_mws'],
#       dtype='object')

# %%
train.drop(drop + ['author'], axis=1).shape
# Out:
# (19579, 20)

# %%
test_set = test.drop(drop, axis=1)

# %%
test_set
# Out:
#       n_char  n_words  n_punct  n_ents  n_chunks  n_unique_words  \
# 0        110       19        3       1         5              19
# 1        330       62        7       1        18              49
# 2        189       33        3       1         8              29
# 3        223       41        5       1         8              34
# 4         53       11        1       0         3              11
# 5        202       32        8       1         6              26
# 6         68       13        2       0         2              11
# 7        155       30        3       0         9              23
# 8        172       28        5       1         7              22
# 9         42        8        2       0         1               8
# 10       257       43        7       1         8              39
# 11       262       49        4       4        15              41
# 12       191       34        4       1         9              30
# 13       149       26        3       0         7              23
# 14        72       14        1       1         3              13
# 15        49        9        1       1         3               9
# 16       100       19        2       0         6              18
# 17       168       31        8       1         6              30
# 18       134       24        5       0         6              23
# 19       129       23        2       1         4              22
# 20        89       16        1       0         4              16
# 21       190       28        5       2         6              26
# 22        61       10        3       1         4               9
# 23        43       10        3       2         5              10
# 24       173       31       10       0         7              26
# 25        59       11        1       0         2              11
# 26       133       24        3       0         6              22
# 27        84       18        2       0         4              15
# 28       226       42        3       0        12              34
# 29       316       59        9       0        17              45
# ...      ...      ...      ...     ...       ...             ...
# 8362     108       20        1       0         7              17
# 8363      99       17        5       0         4              16
# 8364      57       10        1       0         3              10
# 8365      94       19        4       0         5              18
# 8366     246       43        5       1        14              35
# 8367     200       35        4       3         9              29
# 8368     164       27        5       0         8              23
# 8369     162       29        2       0         8              25
# 8370     232       36        3       0         6              30
# 8371      52        8        2       0         1               8
# 8372      57       10        1       0         4              10
# 8373     145       28        9       3         6              22
# 8374      87       18        2       0         5              16
# 8375     100       17        2       2         4              17
# 8376     188       33        4       1         9              28
# 8377     205       44        4       1        11              38
# 8378      85       14        1       0         3              14
# 8379     116       21        2       0         5              18
# 8380     162       29        4       1         9              25
# 8381      93       19        1       0         6              15
# 8382      49        8        2       0         2               8
# 8383     250       40        2       1        11              33
# 8384     107       21        1       1         5              19
# 8385     419       70       11       3        19              55
# 8386     183       33        3       1         8              28
# 8387      42        9        1       0         2               9
# 8388      34        7        1       0         3               7
# 8389     150       25        2       0         5              24
# 8390     197       38        3       0         8              33
# 8391     247       38        5       0         8              33
#
#       n_stop_words  char_by_word    nb_ctv_eap    nb_ctv_hpl    nb_ctv_mws  \
# 0                8      4.684211  1.545984e-02  3.312183e-04  9.842089e-01
# 1               34      4.225806  9.999945e-01  3.446735e-06  2.087760e-06
# 2               16      4.666667  2.215611e-01  7.783635e-01  7.545684e-05
# 3               22      4.341463  8.661980e-01  1.338018e-01  2.889649e-07
# 4                6      3.818182  9.732482e-01  2.003748e-02  6.714317e-03
# 5               14      5.093750  9.538263e-01  4.603862e-02  1.350576e-04
# 6                9      4.153846  6.870980e-01  2.845756e-01  2.832636e-02
# 7               16      4.100000  4.091325e-04  4.186284e-02  9.577280e-01
# 8               15      5.000000  9.995290e-01  4.707740e-04  2.722910e-07
# 9                4      4.125000  8.133049e-01  6.797533e-02  1.187198e-01
# 10              19      4.837209  2.576586e-02  4.075511e-03  9.701586e-01
# 11              28      4.285714  9.679568e-09  1.000000e+00  1.441015e-10
# 12              17      4.558824  1.377685e-02  9.782499e-01  7.973239e-03
# 13              10      4.653846  4.475325e-05  9.999544e-01  8.037343e-07
# 14               8      4.142857  6.041804e-01  1.136417e-01  2.821778e-01
# 15               4      4.555556  1.612337e-05  1.040369e-05  9.999735e-01
# 16              11      4.210526  8.865326e-02  2.711699e-03  9.086350e-01
# 17              14      4.193548  1.000000e+00  1.252206e-10  1.454134e-09
# 18              12      4.416667  1.430176e-01  2.133837e-01  6.435987e-01
# 19              11      4.565217  4.046234e-02  9.572467e-01  2.290917e-03
# 20               9      4.562500  9.775966e-01  1.279711e-02  9.606260e-03
# 21              17      5.642857  9.883821e-01  2.979639e-04  1.131990e-02
# 22               6      4.900000  1.342732e-01  1.184499e-01  7.472769e-01
# 23               5      3.100000  9.600554e-03  9.868539e-01  3.545562e-03
# 24              13      4.290323  3.687211e-05  6.291631e-08  9.999631e-01
# 25               6      4.363636  7.050971e-01  4.608795e-02  2.488150e-01
# 26              15      4.458333  6.730155e-01  3.243284e-01  2.656071e-03
# 27              11      3.611111  9.906276e-01  6.678994e-03  2.693420e-03
# 28              27      4.333333  7.751714e-01  1.438730e-04  2.246847e-01
# 29              35      4.220339  5.826077e-02  8.625593e-08  9.417391e-01
# ...            ...           ...           ...           ...           ...
# 8362            12      4.400000  2.723853e-03  1.833370e-04  9.970928e-01
# 8363            10      4.588235  9.865059e-01  7.507639e-04  1.274337e-02
# 8364             5      4.700000  6.921590e-03  3.887671e-02  9.542017e-01
# 8365            10      3.789474  8.033927e-01  3.375828e-02  1.628491e-01
# 8366            21      4.627907  3.653592e-07  1.542717e-11  9.999996e-01
# 8367            18      4.628571  9.698012e-01  8.034798e-04  2.939535e-02
# 8368            16      4.925926  1.427760e-03  1.536629e-04  9.984186e-01
# 8369            14      4.551724  8.737065e-04  1.407320e-03  9.977190e-01
# 8370            21      5.388889  6.299663e-01  6.539490e-06  3.700271e-01
# 8371             3      5.375000  3.817508e-01  3.545271e-01  2.637220e-01
# 8372             5      4.700000  9.142726e-01  2.483845e-02  6.088892e-02
# 8373            10      3.928571  1.035664e-14  1.000000e+00  6.017264e-15
# 8374            11      3.777778  6.624181e-01  3.273635e-01  1.021839e-02
# 8375             7      4.823529  2.480197e-02  4.789256e-06  9.751932e-01
# 8376            15      4.606061  9.970180e-01  2.862816e-03  1.192134e-04
# 8377            24      3.613636  2.882524e-03  9.971175e-01  9.262211e-10
# 8378             7      5.071429  4.338730e-02  2.706148e-01  6.859979e-01
# 8379            11      4.476190  2.827431e-03  9.968155e-01  3.571050e-04
# 8380            17      4.482759  5.443715e-07  1.699936e-09  9.999995e-01
# 8381            11      3.894737  9.983599e-01  5.213687e-04  1.118682e-03
# 8382             4      5.000000  8.819980e-01  8.373569e-02  3.426626e-02
# 8383            17      5.225000  7.736958e-09  1.000000e+00  1.231400e-10
# 8384            13      4.142857  9.998495e-01  2.001161e-05  1.305117e-04
# 8385            39      4.842857  9.999996e-01  3.725787e-07  4.897520e-08
# 8386            17      4.484848  1.043098e-02  9.895354e-01  3.361777e-05
# 8387             6      3.666667  5.528975e-01  1.067009e-01  3.404016e-01
# 8388             3      3.857143  2.876112e-02  3.137581e-02  9.398631e-01
# 8389            12      4.960000  9.999095e-01  2.288142e-05  6.758543e-05
# 8390            20      4.131579  3.954497e-04  2.115012e-06  9.996024e-01
# 8391            20      5.394737  1.167297e-02  9.883251e-01  1.912801e-06
#
#       nb_tfv_eap  nb_tfv_hpl  nb_tfv_mws  nb_char_eap  nb_char_hpl  \
# 0       0.230652    0.098221    0.671127     0.232347     0.012655
# 1       0.700198    0.136107    0.163695     0.983572     0.005594
# 2       0.503695    0.428797    0.067507     0.469981     0.509879
# 3       0.663662    0.296392    0.039946     0.844240     0.137173
# 4       0.802988    0.117125    0.079887     0.814009     0.049216
# 5       0.635524    0.278847    0.085629     0.958408     0.009951
# 6       0.464174    0.474286    0.061539     0.952083     0.029854
# 7       0.122817    0.171688    0.705495     0.190647     0.138398
# 8       0.878366    0.095923    0.025711     0.996014     0.002152
# 9       0.607174    0.180903    0.211923     0.926659     0.042538
# 10      0.265522    0.198597    0.535882     0.485454     0.108217
# 11      0.077065    0.882616    0.040320     0.248400     0.734028
# 12      0.386080    0.263352    0.350568     0.805417     0.061325
# 13      0.228223    0.686754    0.085023     0.552344     0.394901
# 14      0.529983    0.231277    0.238740     0.747537     0.092433
# 15      0.041664    0.019566    0.938771     0.024953     0.004526
# 16      0.379950    0.212757    0.407293     0.717482     0.024317
# 17      0.939970    0.020478    0.039552     0.995721     0.000647
# 18      0.221256    0.268915    0.509829     0.829882     0.014011
# 19      0.329681    0.566320    0.103999     0.770008     0.123036
# 20      0.803697    0.079585    0.116718     0.952691     0.021277
# 21      0.866239    0.051003    0.082759     0.959971     0.011164
# 22      0.281633    0.224130    0.494237     0.634695     0.131893
# 23      0.172475    0.747328    0.080197     0.534661     0.220209
# 24      0.171263    0.063165    0.765573     0.706839     0.012606
# 25      0.699674    0.059029    0.241297     0.825928     0.022391
# 26      0.567723    0.310085    0.122192     0.912596     0.041852
# 27      0.613122    0.161229    0.225649     0.937661     0.036544
# 28      0.531499    0.113505    0.354996     0.628582     0.011740
# 29      0.421963    0.038820    0.539217     0.908331     0.001681
# ...          ...         ...         ...          ...          ...
# 8362    0.168302    0.053809    0.777888     0.117894     0.009655
# 8363    0.682725    0.143115    0.174160     0.915447     0.018413
# 8364    0.195239    0.216771    0.587990     0.291952     0.109386
# 8365    0.578170    0.227361    0.194470     0.643131     0.119640
# 8366    0.201845    0.024616    0.773539     0.626098     0.006961
# 8367    0.529691    0.110726    0.359584     0.764700     0.043618
# 8368    0.208271    0.098951    0.692777     0.677286     0.036164
# 8369    0.278400    0.216433    0.505166     0.392171     0.058656
# 8370    0.392623    0.114515    0.492862     0.918479     0.004618
# 8371    0.421515    0.294340    0.284145     0.708659     0.160889
# 8372    0.654397    0.096031    0.249572     0.909420     0.018342
# 8373    0.067171    0.871581    0.061248     0.004737     0.993871
# 8374    0.519701    0.331915    0.148383     0.816693     0.110131
# 8375    0.413291    0.050143    0.536566     0.469389     0.034255
# 8376    0.688313    0.204740    0.106947     0.871947     0.019363
# 8377    0.440239    0.471832    0.087929     0.701787     0.251513
# 8378    0.367027    0.230105    0.402868     0.802792     0.057485
# 8379    0.312116    0.555927    0.131957     0.434692     0.459596
# 8380    0.036848    0.008217    0.954935     0.227446     0.001860
# 8381    0.830594    0.084589    0.084818     0.955544     0.036375
# 8382    0.472719    0.257074    0.270207     0.886761     0.026424
# 8383    0.118864    0.793433    0.087703     0.436161     0.542605
# 8384    0.773443    0.081005    0.145552     0.935425     0.012688
# 8385    0.780455    0.083131    0.136415     0.973303     0.002493
# 8386    0.325479    0.499343    0.175178     0.684621     0.189649
# 8387    0.465076    0.201113    0.333810     0.893675     0.006795
# 8388    0.143808    0.098551    0.757642     0.142669     0.031854
# 8389    0.640036    0.143265    0.216698     0.980755     0.003397
# 8390    0.291499    0.090882    0.617619     0.572242     0.016014
# 8391    0.321968    0.580212    0.097821     0.894720     0.093110
#
#       nb_char_mws    nb_ent_eap    nb_ent_hpl    nb_ent_mws
# 0        0.754998  5.823803e-02  4.312031e-04  9.413308e-01
# 1        0.010834  9.999484e-01  3.900615e-05  1.257352e-05
# 2        0.020140  1.628833e-01  8.371049e-01  1.173201e-05
# 3        0.018588  9.387625e-01  6.123734e-02  1.704583e-07
# 4        0.136775  9.721410e-01  2.100861e-02  6.850412e-03
# 5        0.031642  9.628292e-01  3.681220e-02  3.586074e-04
# 6        0.018063  6.831698e-01  2.888510e-01  2.797925e-02
# 7        0.670955  4.079373e-04  4.165399e-02  9.579381e-01
# 8        0.001834  9.965947e-01  3.402364e-03  2.891802e-06
# 9        0.030803  8.129888e-01  7.221005e-02  1.148012e-01
# 10       0.406329  1.635636e-03  1.250351e-04  9.982393e-01
# 11       0.017572  2.898478e-03  9.970997e-01  1.811726e-06
# 12       0.133258  4.463266e-03  9.950878e-01  4.489133e-04
# 13       0.052756  3.028753e-05  9.999687e-01  9.948270e-07
# 14       0.160029  4.464226e-02  6.259839e-01  3.293738e-01
# 15       0.970521  1.924213e-03  4.565723e-03  9.935101e-01
# 16       0.258200  9.124685e-02  2.918158e-03  9.058350e-01
# 17       0.003633  1.000000e+00  1.571982e-11  4.818110e-11
# 18       0.156107  1.435924e-01  2.269232e-01  6.294844e-01
# 19       0.106955  2.856850e-01  7.104949e-01  3.820090e-03
# 20       0.026032  9.773811e-01  1.321934e-02  9.399572e-03
# 21       0.028866  9.996432e-01  1.675185e-05  3.400812e-04
# 22       0.233412  1.356177e-01  1.396410e-01  7.247413e-01
# 23       0.245129  6.125769e-01  7.374001e-02  3.136831e-01
# 24       0.280554  3.556107e-05  3.776840e-08  9.999644e-01
# 25       0.151681  7.017579e-01  4.649800e-02  2.517441e-01
# 26       0.045551  6.482553e-01  3.490622e-01  2.682451e-03
# 27       0.025796  9.903993e-01  6.940148e-03  2.660502e-03
# 28       0.359678  7.798155e-01  1.569579e-04  2.200276e-01
# 29       0.089988  4.070928e-02  1.137879e-07  9.592906e-01
# ...           ...           ...           ...           ...
# 8362     0.872451  2.578126e-03  1.730112e-04  9.972489e-01
# 8363     0.066140  9.867341e-01  7.435254e-04  1.252242e-02
# 8364     0.598663  7.015033e-03  3.224341e-02  9.607416e-01
# 8365     0.237229  8.010340e-01  3.529243e-02  1.636735e-01
# 8366     0.366941  6.957620e-08  1.145989e-12  9.999999e-01
# 8367     0.191682  9.260809e-01  1.571071e-03  7.234806e-02
# 8368     0.286550  1.124985e-03  1.603603e-04  9.987147e-01
# 8369     0.549173  8.958614e-04  1.488710e-03  9.976154e-01
# 8370     0.076903  6.293355e-01  7.221116e-06  3.706572e-01
# 8371     0.130451  3.795734e-01  3.598885e-01  2.605381e-01
# 8372     0.072238  9.141559e-01  2.535666e-02  6.048742e-02
# 8373     0.001391  5.727578e-10  1.000000e+00  2.652797e-11
# 8374     0.073176  6.811870e-01  3.091029e-01  9.710112e-03
# 8375     0.496356  4.965477e-01  2.408349e-04  5.032115e-01
# 8376     0.108690  9.989466e-01  1.034441e-03  1.899131e-05
# 8377     0.046700  1.283864e-03  9.987161e-01  4.589796e-11
# 8378     0.139723  4.508526e-02  2.479047e-01  7.070101e-01
# 8379     0.105712  2.423671e-03  9.972202e-01  3.561218e-04
# 8380     0.770694  9.018620e-07  1.852803e-09  9.999991e-01
# 8381     0.008081  9.983946e-01  5.000831e-04  1.105323e-03
# 8382     0.086815  8.776927e-01  8.657671e-02  3.573061e-02
# 8383     0.021234  5.507522e-09  1.000000e+00  3.855023e-11
# 8384     0.051887  9.006850e-01  9.945288e-03  8.936976e-02
# 8385     0.024204  9.999989e-01  1.051996e-06  8.329256e-08
# 8386     0.125729  1.394867e-02  9.860328e-01  1.849866e-05
# 8387     0.099530  5.528919e-01  1.076546e-01  3.394535e-01
# 8388     0.825478  2.887302e-02  3.196867e-02  9.391583e-01
# 8389     0.015848  9.998329e-01  4.757371e-05  1.195011e-04
# 8390     0.411743  3.969300e-04  1.909780e-06  9.996012e-01
# 8391     0.012169  9.831034e-03  9.901673e-01  1.636390e-06
#
# [8392 rows x 20 columns]

# %%
pred = clf.predict_proba(test_set)

# %%
pred
# Out:
# array([[ 0.01762503,  0.00270423,  0.97967076],
#        [ 0.99618465,  0.00152873,  0.00228662],
#        [ 0.0417346 ,  0.95630956,  0.00195586],
#        ...,
#        [ 0.98698491,  0.00923016,  0.00378488],
#        [ 0.04657585,  0.00181697,  0.95160723],
#        [ 0.06907161,  0.92952508,  0.00140326]], dtype=float32)

# %%
authors = ['MWS','EAP','HPL']

# %%
pred_df = pd.DataFrame(pred, columns=authors)

# %%
test.columns
# Out:
# Index(['id', 'text', 'n_char', 'n_words', 'n_punct', 'n_ents', 'n_chunks',
#        'n_unique_words', 'n_stop_words', 'char_by_word', 'text_ent_repl',
#        'text_cleaned', 'nb_ctv_eap', 'nb_ctv_hpl', 'nb_ctv_mws', 'nb_tfv_eap',
#        'nb_tfv_hpl', 'nb_tfv_mws', 'nb_char_eap', 'nb_char_hpl', 'nb_char_mws',
#        'nb_ent_eap', 'nb_ent_hpl', 'nb_ent_mws'],
#       dtype='object')

# %%
pred_df['id'] = test['id']
pred_df = pred_df[['id','EAP','HPL','MWS']]

# %%
pred_df.to_csv('../predictions/xgb3_pred.csv', index=False)
